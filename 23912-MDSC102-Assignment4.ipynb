# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv(r"C:\Users\Msc 1\Desktop\Sumu\MDSC-102 P\wine\wine.data")
dataset
# Out:
#      1  14.23  1.71  2.43  15.6  127   2.8  3.06   .28  2.29   5.64  1.04  \
# 0    1  13.20  1.78  2.14  11.2  100  2.65  2.76  0.26  1.28   4.38  1.05
# 1    1  13.16  2.36  2.67  18.6  101  2.80  3.24  0.30  2.81   5.68  1.03
# 2    1  14.37  1.95  2.50  16.8  113  3.85  3.49  0.24  2.18   7.80  0.86
# 3    1  13.24  2.59  2.87  21.0  118  2.80  2.69  0.39  1.82   4.32  1.04
# 4    1  14.20  1.76  2.45  15.2  112  3.27  3.39  0.34  1.97   6.75  1.05
# ..  ..    ...   ...   ...   ...  ...   ...   ...   ...   ...    ...   ...
# 172  3  13.71  5.65  2.45  20.5   95  1.68  0.61  0.52  1.06   7.70  0.64
# 173  3  13.40  3.91  2.48  23.0  102  1.80  0.75  0.43  1.41   7.30  0.70
# 174  3  13.27  4.28  2.26  20.0  120  1.59  0.69  0.43  1.35  10.20  0.59
# 175  3  13.17  2.59  2.37  20.0  120  1.65  0.68  0.53  1.46   9.30  0.60
# 176  3  14.13  4.10  2.74  24.5   96  2.05  0.76  0.56  1.35   9.20  0.61
#
#      3.92  1065
# 0    3.40  1050
# 1    3.17  1185
# 2    3.45  1480
# ...

# %%
dataset.columns=['Class','Alcohol','Malic acid','Ash','Alcalinity of ash','Magnesium','Total phenols',
'Flavanoids', 'Nonflavanoid phenols','Proanthocyanins','Color intensity','Hue','OD280/OD315 of diluted wines','Proline' ]

dataset
# Out:
#      Class  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0        1    13.20        1.78  2.14               11.2        100
# 1        1    13.16        2.36  2.67               18.6        101
# 2        1    14.37        1.95  2.50               16.8        113
# 3        1    13.24        2.59  2.87               21.0        118
# 4        1    14.20        1.76  2.45               15.2        112
# ..     ...      ...         ...   ...                ...        ...
# 172      3    13.71        5.65  2.45               20.5         95
# 173      3    13.40        3.91  2.48               23.0        102
# 174      3    13.27        4.28  2.26               20.0        120
# 175      3    13.17        2.59  2.37               20.0        120
# 176      3    14.13        4.10  2.74               24.5         96
#
#      Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0             2.65        2.76                  0.26             1.28
# ...

# %%
df = dataset.copy()

sns.countplot(x=df['Class'])
# Out:
# <Axes: xlabel='Class', ylabel='count'>

# %% [markdown]
# **Inference: There are more class 2 data points in the given data-set**

# %%
i=1
plt.figure(figsize=(25,30))
for feature in df:
    if feature!='Class' and feature!='Alcohol':
        plt.subplot(4,3,i)
        sns.scatterplot(x=df[feature], y=df['Alcohol'], hue=df['Class'])
        plt.grid()
        i+=1

# %% [markdown]
# Inferences:
# 1) Affect of 'Malic Acid' on Alcohol:
# Class 1: Less 'malic acid' (Usually below 2) leads to more Alcohol
# Class 2: Less 'malic acid' (Usually below 2) leads to less alcohol
# Class 3: Corelation coefficient might be 0, data points are scattered and no inference can be made
#
# 2) Affect of 'Ash' on Alcohol:
# Class 1: 'Ash' levels of above 2.25 leads to more Alcohol
# Class 2: For any 'Ash' levels, alcohol is usually under 13.0 most of the times
# Class 3: Slightly positive corelation coefficient. Alcohol levels are between 12-24 most of the times.
#
# 3) Affect of 'Alcalinity of Ash' on Alcohol:
# Class 1: For low levels of 'Alcalinity of Ash' itself, alcohol levels are very high, almost always above 13.
# Class 2: For any 'Alcalinity of Ash' levels, alcohol is usually under 13.0 most of the times
# Class 3: No inference can be made
#
# 4) Affect of 'Magnesium' on Alcohol:
# Class 1: For 'Magnesium' levls of 90-120, alcohol levels are very high, almost always above 13.
# Class 2: Alcohol levels are always under 13, no matter what 'Magnesium' levels are.
# Class 3: Alcohol levels are between 12 and 14.
#
# 5) Affect of 'Total phoenols' on Alcohol:
# Class 1: High levels of 'Total phoenols' will lead to high levels of alcohol.
# Class 2: Alcohol levels are always under 13, no matter what 'Total phoenols' levels are.
# Class 3: For low levels of 'Total phoenols' itself, alcohol levels are high
#
# 6) Affect of 'Flavanoids' on Alcohol:
# Class 1: For 'Flavanoids' levls of 2-4, alcohol levels are very high, almost always above 13.
# Class 2: For 'Flavanoids' levls of 1-3, alcohol levels are less, almost always below 13.
# Class 3: For 'Flavanoids' levls under 1, alcohol levels can range anywhere between 12-14
#
# 7) Affect of 'Non Flavanoid phenols' on Alcohol:
# Class 1: For any range of 'Non Flavanoid phenols', Alcohol levels are usually always above 13.
# Class 2: For any range of 'Non Flavanoid phenols', Alcohol levels are mostly below 13.
# Class 3: No inference can be made.
#
# 8) Affect of 'Proanthocyanins' on Alcohol:
# Class 1: For 'Proanthocyanins' levls of 1.5-2.5, alcohol levels are usually in the range 13-14.5.
# Class 2: For any range of 'Proanthocyanins', Alcohol levels are mostly below 13.
# Class 3: For 'Proanthocyanins' levls of 0.5-1.5, alcohol levels are usually in the range 12-14.
#
# 9) Affect of 'Color intensity' on Alcohol:
# Class 1: For 'Color intensity' levls of 4-8, alcohol levels are slightly increasing starting from 13.
# Class 2: For lower levels of 'Color intensity', alcohol levels are low.
# Class 3: As 'Color intensity' increases, there is a slight rise in Alcohol levels.
#
# 10) Affect of 'Hue' on Alcohol:
# Class 1: For 'Hue' levls of 0.8-1.2, alcohol levels are mostly above 13.
# Class 2: Alcohol levels are under 13 for any range of 'Hue'.
# Class 3: No inference can be made.
#
# 11) Affect of 'OD280/OD315 of diluted wines' on Alcohol:
# Class 1: Starting from 'diluted wines' of level 2.5, alcohol levels are rising.
# Class 2: For any range, alcohol levels are under 13
# Class 3: No inference can be made.
#
# 12) Affect of 'Proline' on Alcohol:
# Class 1: As 'Proline' levels increase, Alcohol levels also increase
# Class 2: For low levels of 'Proline', Alcohol levels are also low
# Class 3: No inference can be made

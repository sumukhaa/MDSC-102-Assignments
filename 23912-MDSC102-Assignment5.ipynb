# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv(r"C:\Users\Msc 1\Desktop\Sumu\MDSC-102 P\wine\wine.data")

dataset.columns=['Class','Alcohol','Malic acid','Ash','Alcalinity of ash','Magnesium','Total phenols',
'Flavanoids', 'Nonflavanoid phenols','Proanthocyanins','Color intensity','Hue','OD280/OD315 of diluted wines','Proline' ]

df = dataset.copy()

df
# Out:
#      Class  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0        1    13.20        1.78  2.14               11.2        100
# 1        1    13.16        2.36  2.67               18.6        101
# 2        1    14.37        1.95  2.50               16.8        113
# 3        1    13.24        2.59  2.87               21.0        118
# 4        1    14.20        1.76  2.45               15.2        112
# ..     ...      ...         ...   ...                ...        ...
# 172      3    13.71        5.65  2.45               20.5         95
# 173      3    13.40        3.91  2.48               23.0        102
# 174      3    13.27        4.28  2.26               20.0        120
# 175      3    13.17        2.59  2.37               20.0        120
# 176      3    14.13        4.10  2.74               24.5         96
#
#      Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0             2.65        2.76                  0.26             1.28
# ...

# %%
i=1
plt.figure(figsize=(18,25))
for feature in df:
    if feature!='Class' and feature!='Alcohol':
        plt.subplot(4,3,i)
        sns.boxplot(x=df['Class'],y=df[feature], hue=df['Class'])
        i+=1

# %% [markdown]
# Inferences:
# 1) From Box plot of 'Malic Acid':
# Class 1: Right skewed
# Class 2: Right skewed
# Class 3: Close to Normal distribution
#
# 2) From Box plot of 'Ash' :
# Class 1: Right skewed
# Class 2: Left skewed
# Class 3: Close to Normal distribution
#
# 3) From Box plot of 'Alcalinity of Ash' :
# Class 1: Left skewed
# Class 2: Right skewed
# Class 3: Right skewed
#
# 4) From Box plot of 'Magnesium' :
# Class 1: Right skewed
# Class 2: Right skewed
# Class 3: Right skewed
#
# 5) From Box plot of 'Total phoenols' :
# Class 1: Left skewed
# Class 2: Close to Normal distribution
# Class 3: Left skewed
#
# 6) From Box plot of 'Flavanoids' :
# Class 1: Right skewed
# Class 2: Close to Normal distribution
# Class 3: Right skewed
#
# 7) From Box plot of 'Non Flavanoid phenols' :
# Class 1: Right skewed
# Class 2: Close to Normal distribution
# Class 3: Left skewed
#
# 8) From Box plot of 'Proanthocyanins' :
# Class 1: Close to Normal distribution
# Class 2: Left skewed
# Class 3: Right skewed
#
# 9) From Box plot of 'Color intensity' :
# Class 1: Right skewed
# Class 2: Close to Normal distribution
# Class 3: Right skewed
#
# 10) From Box plot of 'Hue' :
# Class 1: Close to Normal distribution
# Class 2: Right skewed
# Class 3: Right skewed
#
# 11) From Box plot of 'OD280/OD315 of diluted wines' :
# Class 1: Right skewed
# Class 2: Left skewed
# Class 3: Close to Normal distribution
#
# 12) From Box plot of 'Proline' :
# Class 1: Right skewed
# Class 2: Close to Normal distribution
# Class 3: Right skewed

# %%
i=1
x=1
plt.figure(figsize=(18,55))
for feature in df:
    if feature!='Class' and feature!='Alcohol':

        for y in range(1,4):
            plt.subplot(12,3,i)
            sns.histplot(x=df[df['Class']==y][feature],hue=df['Class'])
            i+=1
            x+=1
        
        if x==4:
            x=1
